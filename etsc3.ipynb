# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
import math

from scipy import *
import scipy.linalg as la

from scipy.special import jn, yn, jn_zeros, yn_zeros

n= 0
x= 0.0

print ("J_%d(%f)= %f" % (n, x, jn(n,x)))

x= 1.0
print ("Y_%d(%f)= %f" % (n, x, yn(n,x)))

x= np.linspace(0, 10, 100)
print (x)
print (len(x))

fig, ax= plt.subplots ()
for n in range (4):
  ax.plot (x, jn(n,x), label=r"$J_%d(x)$"%n)
ax.legend();

fig, bx= plt.subplots ()
for n in range (4):
  bx.plot (x, yn(n,x), label=r"$Y_%d(x)$"%n)
bx.legend();

fig, cx= plt.subplots ()
for n in range (4):
  cx.plot (x, yn(n,x), label=r"$Y_(x)$")
cx.legend();

#To plot sine functions sinx, sin2x, sin3x bassel elements
# Out:
# J_0(0.000000)= 1.000000
# Y_0(1.000000)= 0.088257
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
# ...

# %% [markdown]
# ### Ex 2: Integrate f(x) between limits, $\displaystyle \int_0^3 Y(x) dx$

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from IPython.display import Image

from scipy import *
import scipy.linalg as la

from scipy.integrate import quad, dblquad, tplquad #quadrature


#define a simple function for the integrand
def f(x):
  a=1;
  return a*x**2

x_lower = 0*(-np.pi); x_upper = np.pi; #limits
val, abserr = quad(f, x_lower, x_upper)

print("Integral value= ", val, ", Absolute error= ", abserr)

from scipy.special import jn, yn, jn_zeros, yn_zeros


x= 1.0
print ("Y_%d(%f)= %f" % (n, x, yn(n,x)))
plt.rcParams["figure.figsize"]= [7.00, 3.50]
plt.rcParams["figure.autolayout"]= True
n= 256
X= np.linspace(x_lower, x_upper, n, endpoint=True)
Y=f(X)
print (Y)

fig, ax= plt.subplots()
for n in range(256):
 ax.plot (X, Y, 'm-.', linewidth=7)
 ax.fill_between(X,Y,0,color='magenta', alpha=.1)
 plt.show()
# Out:
# Integral value=  10.335425560099939 , Absolute error=  1.1474627426122306e-13
# Y_0(1.000000)= 0.088257
# [0.00000000e+00 1.51781690e-04 6.07126761e-04 1.36603521e-03
#  2.42850704e-03 3.79454225e-03 5.46414084e-03 7.43730282e-03
#  9.71402817e-03 1.22943169e-02 1.51781690e-02 1.83655845e-02
#  2.18565634e-02 2.56511056e-02 2.97492113e-02 3.41508803e-02
#  3.88561127e-02 4.38649084e-02 4.91772676e-02 5.47931901e-02
#  6.07126761e-02 6.69357253e-02 7.34623380e-02 8.02925141e-02
#  8.74262535e-02 9.48635563e-02 1.02604423e-01 1.10648852e-01
#  1.18996845e-01 1.27648401e-01 1.36603521e-01 1.45862204e-01
#  1.55424451e-01 1.65290261e-01 1.75459634e-01 1.85932570e-01
#  1.96709070e-01 2.07789134e-01 2.19172761e-01 2.30859951e-01
#  2.42850704e-01 2.55145021e-01 2.67742901e-01 2.80644345e-01
#  2.93849352e-01 3.07357923e-01 3.21170056e-01 3.35285754e-01
#  3.49705014e-01 3.64427838e-01 3.79454225e-01 3.94784176e-01
#  4.10417690e-01 4.26354768e-01 4.42595408e-01 4.59139613e-01
# ...

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from IPython.display import Image

from scipy import *
import scipy.linalg as la

from scipy.integrate import quad, dblquad, tplquad #quadrature
import math
from scipy.special import jn, yn, jn_zeros, yn_zeros

def integrand(x,n):
  n=1;
  return jn(n,x)

x_lower=0; x_upper=10;
val, abserr= quad(integrand, x_lower, x_upper, args=(3,))
print(val,abserr)
# Out:
# 1.2459357644513482 1.1600766172282117e-12

# %%
### Ex 3: Integrate between limits, $\dispalystyle \int_0^{10} 3_0(x) dx$

# %% [markdown]
# ### Ex : Integrate between limits, $\int_0^{10}\int_0^{10} e^{(-x^2-y^2)}\, dx\, dy$

# %%
from math import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
from scipy import *

def integrand(x,y):
  return exp(-x**2-y**2)

x_lower=0; x_upper=10
y_lower=0; y_upper=10

val, abserr= dblquad(integrand, x_lower, x_upper, lambda x: y_lower, lambda x: y_upper)
print (val,abserr)
# Out:
# 0.7853981633974476 1.3753098510194181e-08

# %% [markdown]
# ### Ex : Compute $\int_ε^1\int_δ^1 log(x+y)\, dx\, dy$, where

# %%
from math import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Image
from scipy import *

def integrand(x,y):
  return log(x+y)

x_lower=0.01; x_upper=1
y_lower=0.001; y_upper=1

val, abserr= dblquad(integrand, x_lower, x_upper, lambda x: y_lower, lambda x: y_upper)
print (val,abserr)
# Out:
# -0.10306940182946148 1.15967844959685e-08

# %%
# extract data from array

from scipy import *
from numpy import *

V1=array([1,2,4,5])
print(V1)

M1=array([[1,complex(2,0),3],[3,4,5],[0,9,2]]) #\
print('\n M1=',M1)

dd=M1[:,1]
print('\n dd=',dd)
# Out:
# [1 2 4 5]
#
#  M1= [[1.+0.j 2.+0.j 3.+0.j]
#  [3.+0.j 4.+0.j 5.+0.j]
#  [0.+0.j 9.+0.j 2.+0.j]]
#
#  dd= [2.+0.j 4.+0.j 9.+0.j]

# %%
from scipy import *
from numpy import *
